# %%
import math
import numpy as np
from activation_functions import activations as act
global data

# %%
data = np.arange(-5.0,5.0,0.01)

# %%
def make_plot(x,y):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    plt.plot(x,y)
    plt.grid()
    plt.show()

# %%
# tanh plot
x,y = act(data).tanh()
make_plot(x,y)

# %%
#relu
x,y = act(data).relu()
make_plot(x,y)

# %%
#Sigmoid
x,y = act(data).sigmoid()
make_plot(x,y)

# %%
#Gaussian
x,y = act(data).gaussian()
make_plot(x,y)

# %%
#Step
x,y = act(data).step()
make_plot(x,y)

# %%
#Softplus
x,y = act(data).softplus()
make_plot(x,y)

# %%
#Leaky RELU
x,y = act(data).leaky_relu()
make_plot(x,y)
