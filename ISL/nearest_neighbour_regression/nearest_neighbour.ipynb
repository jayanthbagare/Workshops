# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("dark")

# %%
# generate random numbers for each 0.5 step timepoint
df = pd.DataFrame(columns=["x","y"])
for i in range(10000):
    x = np.random.randint(1,20)
    y = np.random.rand()
    df.loc[len(df)] = [x,y]

# %%
sns.scatterplot(data=df,x="x",y="y",marker="+",color="0.2")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
for i in range(20):
    df1 = df.query("x == i")
    df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     196             if self.has_resolvers:
# --> 197                 return self.resolvers[key]
#     198
#
# ~/anaconda3/lib/python3.9/collections/__init__.py in __getitem__(self, key)
#     940                 pass
# --> 941         return self.__missing__(key)            # support subclasses that define __missing__
#     942
#
# ~/anaconda3/lib/python3.9/collections/__init__.py in __missing__(self, key)
#     932     def __missing__(self, key):
# --> 933         raise KeyError(key)
#     934
#
# KeyError: 'i'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
