# %%
words = open('names.csv','r').read().splitlines()

# %%
b = {}
for w in words:
    chs = ['<S>'] + list(w) + ['<E>'] 
    for ch1,ch2 in zip(chs,chs[1:]):
        bigram = (ch1,ch2)
        b[bigram] = b.get(bigram,0) + 1

# %%
sb = dict(sorted(b.items(),key=lambda x:x[1],reverse=True))

# %%
import torch

# %%
N = torch.zeros((27,27),dtype=torch.int32)

# %%
chars = sorted(list(set(''.join(words))))
stoi = {s:i+1 for i,s in enumerate(chars)}
stoi["."] = 0

# %%
itos = {i:s for s,i in stoi.items()}

# %%
for w in words:
    chs = ['.'] + list(w) + ['.'] 
    for ch1,ch2 in zip(chs,chs[1:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        N[ix1,ix2] += 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(16,16))
plt.imshow(N,cmap="Blues")
for i in range(27):
    for j in range(27):
        chstr = itos[i]+itos[j]
        plt.text(j,i,chstr,ha="center",va="bottom",color="gray")
        plt.text(j,i,N[i,j].item(),ha="center",va="top",color="gray")
plt.axis("off")
# Out:
# (-0.5, 26.5, 26.5, -0.5)

# %%
N[0]
# Out:
# tensor([   0, 4609, 1547, 1524, 1869, 1443,  480,  849,  974,  637, 2487, 3032,
#         1562, 2911, 1408,  382,  862,   85, 2020, 3008, 1349,  133,  532,  276,
#          131,  572,  882], dtype=torch.int32)

# %%
p = N[0].float()
p = p / p.sum()
p
# Out:
# tensor([0.0000, 0.1296, 0.0435, 0.0429, 0.0526, 0.0406, 0.0135, 0.0239, 0.0274,
#         0.0179, 0.0699, 0.0853, 0.0439, 0.0819, 0.0396, 0.0107, 0.0242, 0.0024,
#         0.0568, 0.0846, 0.0379, 0.0037, 0.0150, 0.0078, 0.0037, 0.0161, 0.0248])

# %%
g = torch.Generator().manual_seed(2147483647)
ix = torch.multinomial(p,num_samples=1,replacement=True,generator=g).item()
itos[ix]
# Out:
# '.'

# %%
#Ok now to do some name generation using bigram generation
g = torch.Generator().manual_seed(2147483647)

for i in range(10):
    out = []
    ix = 0
    while True:
        p = N[ix].float()
        p = p / p.sum()
        ix = torch.multinomial(p,num_samples=1,replacement=True,generator=g).item()
        out.append(itos[ix])
        if ix == 0:
            break
    print(''.join(out))
# Out:
# junide.
# janasah.
# p.
# cona.
# a.
# nn.
# kui.
# ritolian.
# juee.
# ksahnaauranilevias.
